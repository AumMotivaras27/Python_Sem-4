# %%
# UDP 
import socket
host=socket.gethostname()
print(host)
port=5000
addr=(host,port)
client_socket=socket.socket()
client_socket.connect(addr)
msg=input("==>")
while msg!="":
    client_socket.send(msg.encode())
    data=client_socket.recv(1024).decode()
    print("received from server",data)
    msg=input("==>")
client_socket.close()

# %%
import requests,json
api_key="442de44552f64459ab7240eeb6128559"
city=input("enter city name:")
response=requests.get(url)
coordinates=response.json()
print(coordinates)

# %%
import requests,json
api_key="fb197cd5b99d7ede47cd02216a9f9dfe"
city = input("Enter City Name:- ")
url = "http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_key
response = requests.get(url)
coordinates = response.json()
print(coordinates)
lat = str(coordinates[0]['lat'])
lon = str(coordinates[0]['lon'])
print("Latitude = ",lat)
print("Longitude = ",lon)
print()
cw_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
response = requests.get(cw_url)
current_weather = response.json()
print(json.dumps(current_weather,indent=5))
# Out:
# Enter City Name:- Ahmedabad
# [{'name': 'Ahmedabad', 'local_names': {'he': 'אחמדאבאד', 'ja': 'アフマダーバード', 'ml': 'അഹമ്മദാബാദ്', 'feature_name': 'Ahmedabad', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'hi': 'अहमदाबाद', 'ru': 'Ахмадабад', 'oc': 'Ahmadabad', 'ta': 'அகமதாபாத்', 'de': 'Ahmedabad', 'te': 'అహ్మదాబాద్', 'kn': 'ಅಹ್ಮದಾಬಾದ್', 'en': 'Ahmedabad', 'mr': 'अहमदाबाद', 'gu': 'અમદાવાદ', 'pl': 'Ahmadabad', 'ascii': 'Ahmedabad', 'ar': 'أحمد آباد', 'zh': '艾哈迈达巴德', 'or': 'ଅହମଦାବାଦ', 'eo': 'Ahmadabado', 'ur': 'احمد آباد', 'uk': 'Ахмедабад', 'cs': 'Ahmadábád'}, 'lat': 23.0216238, 'lon': 72.5797068, 'country': 'IN', 'state': 'Gujarat'}]
# Latitude =  23.0216238
# Longitude =  72.5797068
#
# {
#      "coord": {
#           "lon": 72.5797,
#           "lat": 23.0216
#      },
#      "weather": [
#           {
#                "id": 803,
#                "main": "Clouds",
#                "description": "broken clouds",
#                "icon": "04d"
#           }
#      ],
#      "base": "stations",
#      "main": {
# ...

# %%
http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API key}
import requests,json
api_key="fb197cd5b99d7ede47cd02216a9f9dfe"
city = input("Enter City Name:- ")
url = "http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_key
response = requests.get(url)
coordinates = response.json()
print(coordinates)
lat = str(coordinates[0]['lat'])
lon = str(coordinates[0]['lon'])
print("Latitude = ",lat)
print("Longitude = ",lon)
print()
cw_url = f"https://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}"
response = requests.get(cw_url)
current_weather = response.json()
print(json.dumps(current_weather,indent=5))
# Out:
#   File "<ipython-input-7-42588f4c00aa>", line 1
#     http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API key}
#          ^
# SyntaxError: invalid syntax

# %%
# api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API key}
import requests,json
api_key="fb197cd5b99d7ede47cd02216a9f9dfe"
url=f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}&units=metric"
response = requests.get(url)
five_day=response.json()
D={"date_time":[],"temp":[],"pressure":[],"humidity":[],"weather":[]}
for i in five_day["list"]:
    D["date_time"].append(i["dt_txt"])
    D["temp"].append(i['main']["temp"])
    D["pressure"].append(i['main']["pressure"])
    D["humidity"].append(i['main']["humidity"])
    D["weather"].append(i["weather"][0]["description"])
     
import pandas as pd
df=pd.DataFrame(D)
print(df)
print(df.head(40))
# Out:
#               date_time   temp  pressure  humidity           weather
# 0   2025-05-29 09:00:00  38.91       997        35  scattered clouds
# 1   2025-05-29 12:00:00  40.65       995        28  scattered clouds
# 2   2025-05-29 15:00:00  33.81       997        52         clear sky
# 3   2025-05-29 18:00:00  31.96       998        63         clear sky
# 4   2025-05-29 21:00:00  32.14       997        55         clear sky
# 5   2025-05-30 00:00:00  30.13       998        65         clear sky
# 6   2025-05-30 03:00:00  31.90       999        54         clear sky
# 7   2025-05-30 06:00:00  37.76       998        30         clear sky
# 8   2025-05-30 09:00:00  43.06       995        13         clear sky
# 9   2025-05-30 12:00:00  41.49       995        16         clear sky
# 10  2025-05-30 15:00:00  36.54       997        23         clear sky
# 11  2025-05-30 18:00:00  32.96       999        49  scattered clouds
# 12  2025-05-30 21:00:00  30.29      1000        62  scattered clouds
# ...

# %%
# web scrapping 
import requests
from bs4 import BeautifulSoup
url="https://subslikescript.com/movie/Titanic-120338"
results=requests.get(url)
content=results.text
soup=BeautifulSoup(content,"html.parser")
# print(soup.prettify()) 
movie=soup.find("h1").text
# print(movie)
# moviee=soup.find("pre").text
# print(moviee)

# %%
import requests 
from bs4 import BeautifulSoup
website="https://subslikescript.com/movie/Titanic-120338"
content=requests.get(website)
content
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(content.text,"html.parser")
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Titanic (1997) Movie Script
#  | Subs like Script
#   </title>
#   <meta "="" content="    Read " created="" from="" movie="" name="description" script,="" srt="" subtitles="" titanic"=""/>
#   <meta content="    transcript, movie, subtitles, scripts, film, video, media, subs, srt
# " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
soup.find("h1")# give full movie name 
soup.find("h1").text.strip()# give only content
# Out:
# 'Titanic (1997) - full transcript'

# %%
script=soup.find("div",class_="full-script")
script=script.text.strip()
script
# Out:
# '13 meters. You should see it.\n\n\nOkay, take her up and over the bow rail.\n\n\nMir 2, we\'re going over the bow.\nStay with us.\n\n\nOkay, quiet. We\'re rolling.\n\n\nSeeing her coming out of the\ndarkness like a ghost ship...\n\n\nstill gets me every time.\n\n\nTo see the sad ruin of the\ngreat ship sitting here...\n\n\nwhere she landed at\n2:30 in the morning\n\n\nof April 15, 1912...\n\n\nafter her long fall...\n\n\nfrom the world above.\n\n\nYou are so full of shit, boss.\n\n\nDive 6. Here we are again\non the deck of Titanic.\n\n\n21/2 miles down. 3,821 meters.\n\n\nThe pressure outside is\n31/2 tons per square inch.\n\n\nThese windows are\n9 inches thick.\n\n\nIf they go, it\'s sayonara\nin two microseconds.\n\n\nAll right, enough of that bullshit.\n\n\nJust put her down on the roof of\nthe officers\' quarters like yesterday.\n\n\nMir 2, we\'re landing right over the\nGrand Staircase. You guys set to launch?\n\n\nYeah, Brock. Launching Dunkin now.\nGo, Charlie.\n\n\n- All ri
# ...

# %%
with open("titanic.txt","w",encoding="utf-8") as f:
    f.write(script)

# %%
import requests 
from bs4 import BeautifulSoup
website="https://www.politifact.com/factchecks/list/"
content=requests.get(website)
content
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(content.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description">
#    <meta content="all" name="robots">
#     <meta content="PolitiFact" name="publisher"/>
#     <meta content="PolitiFact" name="twitter:username">
#      <meta content="summary" name="twitter:card">
#       <meta content="PolitiFact" name="twitter:site"/>
#       <meta content="" name="twitter:url">
#        <meta content="" name="twitter:title"/>
#        <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %%
# soup.find("h1")# give full movie name 
# soup.find("h1").text.strip()# give only content

# %%
frame=[]
l=soup.find_all("li",class_="o-listicle__item")
for i in links:
    statements=i.find("div",class_="m-statement__quote").text.strip()
    link="https://www.politifact.com"
    link+=i.find("div",class_="m-statement__body").find("a")["href"].strip()
    date=i.find("div",class_="m-statement__body").find("footer").text.strip()
    date=date.split("•")[-1]
    source=i.find("a",class_="m-statement__name").text.strip()
    frame.append((statements,link,date,source))
import pandas as pd
df=pd.DataFrame(frame,columns=["statements","link","date","source"])
df
# Out:
# Empty DataFrame
# Columns: [statements, link, date, source]
# Index: []

# %%
import requests 
from bs4 import BeautifulSoup
website="https://indianexpress.com/"
content=requests.get(website)
content
soup=BeautifulSoup(content.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=990" name="viewport">
#    <title>
#     Latest News Today: Breaking News and Top Headlines from India, Entertainment, Business, Politics and Sports | The Indian Express
#    </title>
#    <meta content="163648403825" property="fb:pages"/>
#    <meta content="168619349359" property="fb:pages"/>
#    <meta content="185763818464532" property="fb:pages"/>
#    <meta content="1494497934210205" property="fb:pages"/>
#    <meta content="1774784956154724" property="fb:pages"/>
#    <meta content="1567211863297748" property="fb:pages"/>
#    <meta content="291465928041678" property="fb:pages"/>
#    <meta content="339520043138547" property="fb:pages"/>
#    <meta content="376556412852346" property="fb:pages"/>
#    <meta content="215732349153100" property="fb:pages"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
script=soup.find("div",class_="top-news")
statement=script.find_all("li")
for i in statement:
    script=i.find("a").text.strip()
    print(script)
# Out:
# Over 2,000 illegal immigrants ‘pushed back’ into Bangladesh since Operation Sindoor
# Rural ministry seeks 12% hike in outlay of Rs 5.23 lakh crore for MGNREGS over 5 years
# ‘Targeted terror attack’: Six injured in Colorado firebombing during pro-Israel event, suspect in custody
# Why assassination of a Union Minister is being discussed 50 yrs later
# How world champion Gukesh took down Magnus Carlsen at Norway Chess
